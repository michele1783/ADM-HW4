# %%
pip install light-famd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np      
import matplotlib.pyplot as plt 
import scipy.io.wavfile 
import subprocess
import librosa
import librosa.display
import IPython.display as ipd
import pandas as pd
from sklearn.decomposition import PCA
from sklearn import preprocessing
from light_famd import FAMD
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

from pathlib import Path, PurePath   
from tqdm.notebook import tqdm

# %%
def convert_mp3_to_wav(audio):  
    """Convert an input MP3 audio track into a WAV file.

    Args:
        audio (str): An input audio track.

    Returns:
        [str]: WAV filename.
    """
    if audio[-3:] == "mp3":
        wav_audio = audio[:-3] + "wav"
        if not Path(wav_audio).exists():
                subprocess.check_output(f"ffmpeg -i {audio} {wav_audio}", shell=True)
        return wav_audio
    
    return audio

def plot_spectrogram_and_picks(track, sr, peaks, onset_env):
    """[summary]

    Args:
        track (np.ndarray): A track.
        sr (int): Sampling rate.
        peaks (np.ndarray): Indices of peaks in the track.
        onset_env (np.ndarray): Vector containing the onset strength envelope.
    """
    times = librosa.frames_to_time(np.arange(len(onset_env)),
                            sr=sr, hop_length=HOP_SIZE)

    plt.figure()
    ax = plt.subplot(2, 1, 2)
    D = librosa.stft(track)
    librosa.display.specshow(librosa.amplitude_to_db(np.abs(D), ref=np.max),
                            y_axis='log', x_axis='time')
    plt.subplot(2, 1, 1, sharex=ax)
    plt.plot(times, onset_env, alpha=0.8, label='Onset strength')
    plt.vlines(times[peaks], 0,
            onset_env.max(), color='r', alpha=0.8,
            label='Selected peaks')
    plt.legend(frameon=True, framealpha=0.8)
    plt.axis('tight')
    plt.tight_layout()
    plt.show()

def load_audio_picks(audio, duration, hop_size):
    """[summary]

    Args:
        audio (string, int, pathlib.Path or file-like object): [description]
        duration (int): [description]
        hop_size (int): 

    Returns:
        tuple: Returns the audio time series (track) and sampling rate (sr), a vector containing the onset strength envelope
        (onset_env), and the indices of peaks in track (peaks).
    """
    try:
        track, sr = librosa.load(audio, duration=duration)
        onset_env = librosa.onset.onset_strength(track, sr=sr, hop_length=hop_size)
        peaks = librosa.util.peak_pick(onset_env, 10, 10, 10, 10, 0.5, 0.5)
    except Error as e:
        print('An error occurred processing ', str(audio))
        print(e)

    return track, sr, onset_env, peaks

# %%
N_TRACKS = 1413
HOP_SIZE = 512
DURATION = 30 # TODO: to be tuned!
THRESHOLD = 0 # TODO: to be tuned!

# %%
data_folder = Path("data/mp3s-32k/")
mp3_tracks = data_folder.glob("*/*/*.mp3")
tracks = data_folder.glob("*/*/*.wav")

# %% [markdown]
# ### Preprocessing

# %%
for track in tqdm(mp3_tracks, total=N_TRACKS):
    convert_mp3_to_wav(str(track))

# %% [markdown]
# ### Audio signals

# %%
for idx, audio in enumerate(tracks):
    if idx >= 2:
        break
    track, sr, onset_env, peaks = load_audio_picks(audio, DURATION, HOP_SIZE)
    plot_spectrogram_and_picks(track, sr, peaks, onset_env)

# %%
peaks
# Out:
# array([  23,  194,  247,  323,  346,  368,  413,  435,  457,  480,  501,
#         523,  545,  567,  589,  610,  632,  643,  654,  674,  697,  720,
#         743,  786,  807,  817,  829,  850,  872,  894,  939,  961,  982,
#        1004, 1025, 1047, 1069, 1091, 1114, 1136, 1180, 1202, 1223, 1245,
#        1267, 1279])

# %%
sr
# Out:
# 22050

# %%
track[9661]
# Out:
# -0.03784437

# %%
onset_env
# Out:
# array([0.       , 0.       , 0.       , ..., 1.3338012, 1.0911108,
#        0.3856156], dtype=float32)

# %% [markdown]
# ### 2.1 Getting your data!

# %%
def clean(df):
    for i in df.columns:
        if df[i].isnull().any() == True:
            if is_numeric_dtype(df[i]) == True:
                df[i] = df[i].fillna(df[i].mean())
            elif is_string_dtype(df[i]) == True:
                    df[i] = df[i].fillna("")

# %% [markdown]
# We upload three different datasets

# %%
tracks = pd.read_csv("tracks.csv")
echonest = pd.read_csv("echonest.csv")
features = pd.read_csv("features.csv")

# %%
tracks_1 = tracks.copy()

# %%
clean(tracks_1)

# %%
tracks_1
# Out:
#         track_id  album_comments   album_date_created  album_date_released  \
# 0              2               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 1              3               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 2              5               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 3             10               0  2008-11-26 01:45:08  2008-02-06 00:00:00
# 4             20               0  2008-11-26 01:45:05  2009-01-06 00:00:00
# ...          ...             ...                  ...                  ...
# 106569    155316               0  2017-03-30 15:20:35  2017-02-17 00:00:00
# 106570    155317               0  2017-03-30 15:20:35  2017-02-17 00:00:00
# 106571    155318               0  2017-03-30 15:20:35  2017-02-17 00:00:00
# 106572    155319               0  2017-03-30 15:20:35  2017-02-17 00:00:00
# 106573    155320               0  2017-03-26 16:22:18  2017-03-26 00:00:00
#
#        album_engineer  album_favorites  album_id  \
# ...

# %%
print(tracks.shape)
tracks.head()
# Out:
# (106574, 53)
#    track_id  album_comments   album_date_created  album_date_released  \
# 0         2               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 1         3               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 2         5               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 3        10               0  2008-11-26 01:45:08  2008-02-06 00:00:00
# 4        20               0  2008-11-26 01:45:05  2009-01-06 00:00:00
#
#   album_engineer  album_favorites  album_id  \
# 0            NaN                4         1
# 1            NaN                4         1
# 2            NaN                4         1
# 3            NaN                4         6
# 4            NaN                2         4
#
#                            album_information  album_listens album_producer  \
# 0                                    <p></p>           6073            NaN
# 1                                    <p></p>           6073            NaN
# ...

# %%
print(echonest.shape)
echonest
# Out:
# (13129, 248)
#        track_id  audio_features_acousticness  audio_features_danceability  \
# 0             2                     0.416675                     0.675894
# 1             3                     0.374408                     0.528643
# 2             5                     0.043567                     0.745566
# 3            10                     0.951670                     0.658179
# 4           134                     0.452217                     0.513238
# ...         ...                          ...                          ...
# 13124    124857                     0.007592                     0.790364
# 13125    124862                     0.041498                     0.843077
# 13126    124863                     0.000124                     0.609686
# 13127    124864                     0.327576                     0.574426
# 13128    124911                     0.993606                     0.499339
#
#        audio_features_energy  audio_features_instrumentalness  \
# ...

# %%
print(features.shape)
features.head()
# Out:
# (106574, 519)
#    track_id  chroma_cens_kurtosis_01  chroma_cens_kurtosis_02  \
# 0         2                 7.180653                 5.230309
# 1         3                 1.888963                 0.760539
# 2         5                 0.527563                -0.077654
# 3        10                 3.702245                -0.291193
# 4        20                -0.193837                -0.198527
#
#    chroma_cens_kurtosis_03  chroma_cens_kurtosis_04  chroma_cens_kurtosis_05  \
# 0                 0.249321                 1.347620                 1.482478
# 1                 0.345297                 2.295201                 1.654031
# 2                -0.279610                 0.685883                 1.937570
# 3                 2.196742                -0.234449                 1.367364
# 4                 0.201546                 0.258556                 0.775204
#
#    chroma_cens_kurtosis_06  chroma_cens_kurtosis_07  chroma_cens_kurtosis_08  \
# ...

# %% [markdown]
# We have noticed that these three different datasets contain different information about tracks but they have a common column: the track_id. This ID number identifies in unambiguous way the track. We check if there are some missing values in this column

# %%
print(tracks["track_id"].isnull().any())
print(features["track_id"].isnull().any())
print(echonest["track_id"].isnull().any())
# Out:
# False
# False
# False

# %% [markdown]
# So we perform a merge between these three datasets on the column **track_id** and we see that we have picked the rows of *echonest* dataset that are circa 13K while the other two datasets are bigger.

# %%
first_merge = tracks.merge(features, on = "track_id")
dataset = first_merge.merge(echonest, on = "track_id")
dataset
# Out:
#        track_id  album_comments   album_date_created  album_date_released  \
# 0             2               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 1             3               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 2             5               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 3            10               0  2008-11-26 01:45:08  2008-02-06 00:00:00
# 4           134               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# ...         ...             ...                  ...                  ...
# 13124    124857               0  2015-09-09 14:39:58  2006-02-06 00:00:00
# 13125    124862               0  2015-09-09 14:39:58  2006-02-06 00:00:00
# 13126    124863               0  2015-09-09 14:39:58  2006-02-06 00:00:00
# 13127    124864               0  2015-09-09 14:39:58  2006-02-06 00:00:00
# 13128    124911               0  2015-09-11 12:08:44  2010-09-23 00:00:00
#
#       album_engineer  album_favorites  album_id  \
# ...

# %% [markdown]
# We decide to delete the column *metadata_album_date* because it's not a numerical feature, it's full of NaN, circa 10K, and to perform the PCA we need only numerical variables. In addition to this, we think that it is not relevant for our future analysis.

# %%
echonest = echonest.drop(["metadata_album_date", "metadata_album_name"], axis = 1)

# %%
#echonest
scaler = preprocessing.StandardScaler()
echonest_1 = pd.DataFrame(scaler.fit_transform(echonest[echonest.columns[1:9]].values), columns = echonest.columns[1:9])
echonest_1["track_id"] = echonest["track_id"]
echonest_1
print(echonest_1.isnull().any())
# Out:
# audio_features_acousticness        False
# audio_features_danceability        False
# audio_features_energy              False
# audio_features_instrumentalness    False
# audio_features_liveness            False
# audio_features_speechiness         False
# audio_features_tempo               False
# audio_features_valence             False
# track_id                           False
# dtype: bool

# %%
pca = PCA(n_components=2)
pca.fit(echonest_1.iloc[:,0:9])
# Out:
# PCA(n_components=2)

# %%
print(pca.explained_variance_ratio_)
# Out:
# [9.99999991e-01 2.10429820e-09]

# %%
scaler = preprocessing.StandardScaler()
echonest_1 = pd.DataFrame(scaler.fit_transform(echonest[echonest.columns[1:9]].values), columns = echonest.columns[1:9])

# %%
famd = FAMD(n_components=4)
famd.fit(echonest_1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-25a6ff4f8746> in <module>
#       1 famd = FAMD(n_components=4)
# ----> 2 famd.fit(echonest_1)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/light_famd/famd.py in fit(self, X, y)
#      40             self.groups['Categorical'] = cat_cols
#      41         else:
# ---> 42             raise ValueError("FAMD works with categorical and numerical data but " +
#      43                              "you only have numerical data; you should consider using PCA")
#      44
#
# ValueError: FAMD works with categorical and numerical data but you only have numerical data; you should consider using PCA

# %%
print(famd.explained_variance_)

# %% [markdown]
# ## 3. Algorithmic Question

# %% [markdown]
# *You are given a list of integers, A, and another integer s. Write an algorithm that outputs all the pairs in A that equal x.*

# %% [markdown]
# I check all the possible pairs in my list with two for loops. If the sum of a pair is equal to my given sum I store my result.

# %%
def algo(l, s):
    
    result = [] 
    n = len(l)                                #length of the starting list
    
    for i in range(len(l)):                   #first loop starts from the beginning of the list and scan all the list
        for j in range(i+1, len(l)):          #the second loop starts from the next number of the first loop
            if(l[i]+l[j] == s):             #check the given sum 
                result.append((l[i], l[j]))   #append the tuple in my final list 
    
    if len(result) == 0:                      #check if i have found at least one pair
        return("There is not any pair that gives as result " + str(s))
    else:
        return result

# %% [markdown]
# Try the algorithm with some examples.

# %%
l = [7, -2, 8, 2, 6, 4, -7, 2, 1, 3, -3] 
s = 4
algo(l, s)
# Out:
# [(7, -3), (-2, 6), (2, 2), (1, 3)]

# %%
l = [7, -2, 8, 2, 6, 4, -7, 2, 1, 3, -3] 
s = 10
algo(l, s)
# Out:
# [(7, 3), (8, 2), (8, 2), (6, 4)]

# %%
l = [7, -2, 8, 2, 6, 4, -7, 2, 1, 3, -3] 
s = -5
algo(l, s)
# Out:
# [(-2, -3), (2, -7), (-7, 2)]

# %%
l = [7, -2, 8, 2, 6, 4, -7, 2, 1, 3, -3] 
s = 100
algo(l, s)
# Out:
# 'There is not any pair that gives as result 100'
